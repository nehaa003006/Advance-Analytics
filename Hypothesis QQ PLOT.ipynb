# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data=pd.read_csv("tips.csv")
total_bill_series=data["total_bill"]

#Normality test with shapiro-wilk test
shapiro_test = stats.shapiro(total_bill_series)
print("Test statistics (W):", shapiro_test.statistic)
print("p-value",shapiro_test.pvalue)
# Out:
# Test statistics (W): 0.9197187941346584
# p-value 3.3245391868090786e-10

# %%
alpha=0.05
if shapiro_test.pvalue>alpha:
    print("Data is normally distributed")
else:
    print("Data is not normally distributed")
# Out:
# Data is not normally distributed

# %%
#QQ Plot
stats.probplot(total_bill_series,dist="norm",plot=plt)
plt.title('QQ plot of total Bill ')
plt.xlabel("Theoritical Quantities (Normal Distribution)")
plt.ylabel('Orderes Values(Total Bill)')
plt.grid(True)
plt.show()

# %%
df1=pd.read_csv('Rain.csv')

# %%
df1.columns
df1_series= df1['Year']

# %%
#Normality test with shapiro-wilk test
shapiro_test = stats.shapiro(shapiro-  9)
print("Test statistics (W):", shapiro_test.statistic)
print("p-value",shapiro_test.pvalue)
