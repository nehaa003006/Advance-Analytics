# %%
from scipy.stats import binom

# %%
n=5 #Total number of students
k=3 #Number of students who like python
p=0.66 #Probability that a students likes Python

# %%
probability= binom.pmf(k,n,p)
print(probability)
# Out:
# 0.3323453760000002

# %%
n=6
k=4
p=0.75

# %%
probability= binom.pmf(k,n,p)
print(probability)
# Out:
# 0.296630859375

# %%
#a blindfolded marksman finds that on the average, he hits the target 4 times out of 5 .If he fires 4 shots, what is the probability of a) more than 2 hits
# b) at least 3 misses
# 85% borowwers repay loans on time.If a bank gives a loan to 10 people what is the probability that a) more than 7 will repay? b) atleast 3 default?

# %%
p1=(4/5)
print(p1)
# Out:
# 0.8

# %%
p_3_shots=binom.pmf(3,4,p1)
p_4_shots=binom.pmf(4,4,p1)
p_combined= p_3_shots+p_4_shots

# %%
print(p_combined)
# Out:
# 0.8192000000000002

# %%
#misses atleast three 
#that means here we have to calculate that he hits
p_0_hits= binom.pmf(0,4,0.8)
p_1_hits=binom.pmf(1,4,0.8)
p_atleast_3_misses= p_0_hits+p_1_hits

# %%
print(p_atleast_3_misses)
# Out:
# 0.027199999999999974
