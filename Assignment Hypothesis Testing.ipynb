# %% [markdown]
# A courier company deliver parcels in a particular area in 30 minutes . A new GPS system installed has reduced the average time to 28 minutes, when 100 trucks were studied, with a sample SD of 4.2 minutes.Run a two tailed test and one -tailed test

# %% [markdown]
# A battery manufacturer claims that a battery which is used run for 30 hours now runs for more than 30 hours due to new technology . 200 batteries were studied. Average battery time was found to be 29.5 hours with a standard deviation of  8 hours .Run a one-tailed test(right tailed test
# )

# %% [markdown]
# Assignment : FOR three combined Marathon datasets extract the top 25 records with lowest finish time (Official Time column).Check the null hypothesis H0= The average finishing time of the top 25 athlete is 130 minutes . Test it for  alpha =1%, 5% and 10%
