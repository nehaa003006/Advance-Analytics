# %%
import pandas as pd

# %%
#to parse dates as dates while reading the data
df=pd.read_csv("data frame name",parse_date=['the name of the column containing the date'])
df.set_index('day',inplace=True)
