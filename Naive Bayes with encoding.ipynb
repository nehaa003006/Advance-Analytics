# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")

# %%
#Encoding
#encode the gender using the LabelEncoder
le=LabelEncoder()
df['gender']=le.fit_transform(df['gender']) #male=1 or 0 depending on the alphabetical order

# %%
#-------AGE CLEANING + SCALING---------
df['age']=df['age'].fillna(df['age'].median())
scaler=StandardScaler()
df['age_scaled']

# %% [markdown]
# #Assignment 3
# perform naive bayes classification and logistic regression to predict if a bank customer would churn (i.e close bank account) using dataset "Bank Customer Churn Prediction" . Perform encoding and scaling as appropriate . Handle nulls if present
#
# Use Dataset
# https://www.kaggle.com/datasets/tejashvi14/travel-insurance-prediction-data.Predict 'customer travel insurance purchase' column. Perform scaling, encoding null handling , as necessary.
