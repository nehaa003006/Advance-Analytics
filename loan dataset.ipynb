# %%
import pandas as pd

# %%
df=pd.read_csv('loan_approval_dataset.csv')

# %%
N=len(df)
A=len(df[df['loan_status']=='Approved'])
B=len(df[df['cibil_score']>=700])

# %%
#Baye's Theorem
#P_A_given_B=(P_B_given_A*P_A)/P_B

# %%
print("Total Records:", N)
print("Approved Records:",A)
print("Good Credit Count:",B)
print("Approved AND Good Credit:",A_and_B)
print("P(Loan Approved):",P_A)
print("P(Good CIBIL Score):",P_B)
print("P(Good CIBIL Score|Loan was Approved):",P_B_given_A)
print("P(Loan Approved|Good Credit):",P_A_given_B)

#Two new customers walk in, one with CIBIL score 800,a nother with 500
#Bad credit count
bad_credit = N - B #People who got approved but don't have good credit
#P(Loan Approved|Bad Credit)
P_A_given_notB = (A_and_notB /A)*(P_A/(bad_credit/N))
# Out:
# Total Records: 4269
# Approved Records: 2656
# Good Credit Count: 1430
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 print("Approved Records:",A)
#       3 print("Good Credit Count:",B)
# ----> 4 print("Approved AND Good Credit:",A_and_B)
#       5 print("P(Loan Approved):",P_A)
#       6 print("P(Good CIBIL Score):",P_B)
#
# NameError: name 'A_and_B' is not defined

# %%
print("P(Loan Approved|CIBIL Score = 800):",P_A_given_B)#good credit
print("P(Loan Approved |CIBIL Score = 500):",P_A_given_notB)#bad credit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print("P(Loan Approved|CIBIL Score = 800):",P_A_given_B)#good credit
#       2 print("P(Loan Approved |CIBIL Score = 500):",P_A_given_notB)
#
# NameError: name 'P_A_given_B' is not defined
